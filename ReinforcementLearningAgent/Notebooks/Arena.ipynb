# %%
# %cd ReinforcementLearningAgent/
# Out:
# [Errno 2] No such file or directory: 'ReinforcementLearningAgent/'
# /

# %%
# %cd ..
# Out:
# /connect-4-ai-app/ReinforcementLearningAgent

# %%
# !uv run main_arena.py
# Out:
# Running Arena Pipeline
# New game: iteration_1 vs iteration_14
# iteration_14 (YELLOW) Wins
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . R Y . . R .
# Y to play
# 0.03 0.03 0.74 0.13 0.03 0.03 0.03
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . Y . . . .
# . R Y . . R .
# R to play
# 0.15 0.13 0.13 0.18 0.15 0.13 0.13
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . Y . . . .
# . R Y R . R .
# Y to play
# 0.03 0.03 0.77 0.05 0.08 0.03 0.03
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . Y . . . .
# . . Y . . . .
# . R Y R . R .
# R to play
# 0.13 0.15 0.10 0.21 0.21 0.10 0.10
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . Y . . . .
# . . Y R . . .
# . R Y R . R .
# Y to play
# 0.03 0.03 0.74 0.08 0.08 0.03 0.03
# Game ends
#
# New game: iteration_14 vs iteration_1
# iteration_1 (YELLOW) Wins
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . Y . . . .
# . R R . . . .
# ...
