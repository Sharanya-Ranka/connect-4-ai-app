# %%
# %cd ReinforcementLearningAgent/
# Out:
# [Errno 2] No such file or directory: 'ReinforcementLearningAgent/'
# /

# %%
# %cd connect-4-ai-app/ReinforcementLearningAgent/
# Out:
# /connect-4-ai-app/ReinforcementLearningAgent

# %%
# !uv run main_arena.py
# Out:
# Running Arena Pipeline
# Playoff player 20 vs player 32
# Num games=50 WinStats=[18, 2, 26]
# Playoff player 20 vs player 34
# Num games=50 WinStats=[21, 1, 26]
# Playoff player 20 vs player 36
# Num games=50 WinStats=[20, 0, 26]
# Playoff player 30 vs player 32
# Num games=50 WinStats=[18, 1, 27]
# Playoff player 30 vs player 34
# Num games=50 WinStats=[21, 1, 27]
# Playoff player 30 vs player 36
# Num games=50 WinStats=[20, 1, 26]
